# %% [markdown]
# # Indexing

# %%
#Index is an object that stores the access labels for all pandas object.

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Product sales dataset\Sales_v1.xlsx")

# %%
df
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN      1513.0
# 1          Government  Germany      Paseo           NaN      1006.0
# 2          Government   Canada      Paseo           NaN      1725.0
# 3          Government  Germany      Paseo           NaN      1513.0
# 4          Government  Germany       Velo           NaN      1006.0
# 5          Government   France        VTT           NaN      1527.0
# 6          Government   France   Amarilla           NaN      2750.0
# 7          Government   Mexico  Carretera           Low      1210.0
# 8          Government   Mexico  Carretera           Low      1397.0
# 9          Government   France  Carretera           Low      2155.0
# 10         Government   France      Paseo           Low      2155.0
# 11         Government   Canada        VTT           Low       943.5
# 12         Government   Mexico        VTT           Low      1397.0
# ...

# %%
# changing the indexing of the df
df1 = pd.read_excel(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Product sales dataset\Sales_v1.xlsx", index_col= 'Segment')

# %%
df1
# Out:
#                   Country    Product Discount Band  Units Sold  \
# Segment
# Government        Germany  Carretera           NaN      1513.0
# Government        Germany      Paseo           NaN      1006.0
# Government         Canada      Paseo           NaN      1725.0
# Government        Germany      Paseo           NaN      1513.0
# Government        Germany       Velo           NaN      1006.0
# Government         France        VTT           NaN      1527.0
# Government         France   Amarilla           NaN      2750.0
# Government         Mexico  Carretera           Low      1210.0
# Government         Mexico  Carretera           Low      1397.0
# Government         France  Carretera           Low      2155.0
# Government         France      Paseo           Low      2155.0
# Government         Canada        VTT           Low       943.5
# Government         Mexico        VTT           Low      1397.0
# Government         Canada  Carretera           Low      2852.0
# ...

# %%
#df.reset_index(inplace = True)

# %%
#df

# %%
#df.set_index('Segment',inplace=True)

# %%
# reseting the indexing of df
df1.reset_index(inplace=True)

# %%
df1
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN      1513.0
# 1          Government  Germany      Paseo           NaN      1006.0
# 2          Government   Canada      Paseo           NaN      1725.0
# 3          Government  Germany      Paseo           NaN      1513.0
# 4          Government  Germany       Velo           NaN      1006.0
# 5          Government   France        VTT           NaN      1527.0
# 6          Government   France   Amarilla           NaN      2750.0
# 7          Government   Mexico  Carretera           Low      1210.0
# 8          Government   Mexico  Carretera           Low      1397.0
# 9          Government   France  Carretera           Low      2155.0
# 10         Government   France      Paseo           Low      2155.0
# 11         Government   Canada        VTT           Low       943.5
# 12         Government   Mexico        VTT           Low      1397.0
# ...

# %%
df.iloc[40]
# Out:
# Segment                         Government
# Country                             Mexico
# Product                            Montana
# Discount Band                       Medium
# Units Sold                           980.0
# Manufacturing Price                      5
# Sale Price                             350
# Gross Sales                       343000.0
# Discounts                          20580.0
#  Sales                            322420.0
# COGS                              254800.0
# Profit                             67620.0
# Date                   2014-04-01 00:00:00
# Month Number                             4
# Month Name                           April
# Year                                  2014
# Name: 40, dtype: object

# %%
df
# Out:
#               Segment  Country    Product Discount Band  Units Sold  \
# 0          Government  Germany  Carretera           NaN      1513.0
# 1          Government  Germany      Paseo           NaN      1006.0
# 2          Government   Canada      Paseo           NaN      1725.0
# 3          Government  Germany      Paseo           NaN      1513.0
# 4          Government  Germany       Velo           NaN      1006.0
# ..                ...      ...        ...           ...         ...
# 695         Midmarket   Canada      Paseo          High      1614.0
# 696         Midmarket   Canada      Paseo          High      2559.0
# 697        Enterprise  Germany      Paseo          High      1085.0
# 698         Midmarket  Germany      Paseo          High      1175.0
# 699  Channel Partners      USA      Paseo          High       914.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3         350     529550.0       0.00  529550.00
# ...

# %%
#df.reset_index(inplace=True)

# %%
#df

# %%
#Multi-indexing
df.set_index(['Segment','Country'], inplace=True)

# %%
#Sorting the multi-index in ascending or descending order

df.sort_index(ascending=[False,True])

#pd.set_option('display.max.columns', 700)

#df
# Out:
#                             Product Discount Band  Units Sold  \
# Segment          Country
# Small Business   Canada         VTT           NaN      2001.0
#                  Canada    Amarilla           Low      1916.0
#                  Canada         VTT           Low      1874.0
#                  Canada         VTT        Medium      2436.0
#                  Canada     Montana        Medium      1283.0
#                  Canada         VTT        Medium      2134.0
#                  Canada   Carretera        Medium      1094.0
#                  Canada     Montana        Medium      3802.5
#                  Canada        Velo        Medium      3793.5
#                  Canada   Carretera          High      1496.0
#                  Canada        Velo          High       269.0
#                  Canada         VTT          High       269.0
#                  Canada         VTT          High      1496.0
#                  Canada    Amarilla          High       888.0
# ...

# %%
df.loc['Small Business']
# Out:
#            Product Discount Band  Units Sold  Manufacturing Price  Sale Price  \
# Country
# Mexico     Montana           NaN       958.0                    5         300
# Canada         VTT           NaN      2001.0                  250         300
# France         VTT           NaN      2151.0                  250         300
# Mexico   Carretera           Low       494.0                    3         300
# USA        Montana           Low      2301.0                    5         300
# USA        Montana           Low      2498.0                    5         300
# Germany        VTT           Low       986.0                  250         300
# Mexico         VTT           Low       494.0                  250         300
# Germany  Carretera           Low       214.0                    3         300
# Germany        VTT           Low       214.0                  250         300
# Germany   Amarilla           Low       259.0                  260         300
# ...

# %%
df.loc['Small Business', 'Canada']
# Out:
# C:\Users\HP Pavilion\AppData\Local\Temp\ipykernel_17800\3460421225.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['Small Business', 'Canada']
#                           Product Discount Band  Units Sold  \
# Segment        Country
# Small Business Canada         VTT           NaN      2001.0
#                Canada    Amarilla           Low      1916.0
#                Canada         VTT           Low      1874.0
#                Canada         VTT        Medium      2436.0
#                Canada     Montana        Medium      1283.0
#                Canada         VTT        Medium      2134.0
#                Canada   Carretera        Medium      1094.0
#                Canada     Montana        Medium      3802.5
#                Canada        Velo        Medium      3793.5
#                Canada   Carretera          High      1496.0
#                Canada        Velo          High       269.0
# ...
