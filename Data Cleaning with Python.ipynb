# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Python data cleaning dataset.xlsx")
df
# Out:
#     UniqueID           ParcelID             LandUse  \
# 0        2045   007 00 0 125.00       SINGLE FAMILY
# 1       16918   007 00 0,130.00       SINGLE FAMILY
# 2       54582   007 00 0 138.00      ,SINGLE FAMILY
# 3       43070   007 00 0-143.00       SINGLE FAMILY
# 4       22714   007-00 0 149.00       SINGLE FAMILY
# 5       48717   015 14 0 045.00       SINGLE FAMILY
# 6       18367   007 00 0 151.00       SINGLE FAMILY
# 7       19804   007 14 0 002.00       SINGLE FAMILY
# 8       54583   007 14 0 024.00       SINGLE FAMILY
# 9       36500   007 14 0 026.00       SINGLE FAMILY
# 10      19805   007-14 0 034.00       SINGLE FAMILY
# 11      29467  007 14 0A 024.00       SINGLE FAMILY
# 12      10754  007 14 0A 027.00       SINGLE FAMILY
# 13      34751  007 14 0B 010.00  /RESIDENTIAL CONDO
# 14      48717   015 14 0 045.00       SINGLE FAMILY
#
#                           PropertyAddress   SaleDate  SalePrice  \
# ...

# %%
df= df.drop_duplicates()
df
# Out:
#     UniqueID           ParcelID             LandUse  \
# 0        2045   007 00 0 125.00       SINGLE FAMILY
# 1       16918   007 00 0,130.00       SINGLE FAMILY
# 2       54582   007 00 0 138.00      ,SINGLE FAMILY
# 3       43070   007 00 0-143.00       SINGLE FAMILY
# 4       22714   007-00 0 149.00       SINGLE FAMILY
# 5       48717   015 14 0 045.00       SINGLE FAMILY
# 6       18367   007 00 0 151.00       SINGLE FAMILY
# 7       19804   007 14 0 002.00       SINGLE FAMILY
# 8       54583   007 14 0 024.00       SINGLE FAMILY
# 9       36500   007 14 0 026.00       SINGLE FAMILY
# 10      19805   007-14 0 034.00       SINGLE FAMILY
# 11      29467  007 14 0A 024.00       SINGLE FAMILY
# 12      10754  007 14 0A 027.00       SINGLE FAMILY
# 13      34751  007 14 0B 010.00  /RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df=df.drop(columns = ['Acreage', 'TaxDistrict'])
df
# Out:
#     UniqueID           ParcelID             LandUse  \
# 0        2045   007 00 0 125.00       SINGLE FAMILY
# 1       16918   007 00 0,130.00       SINGLE FAMILY
# 2       54582   007 00 0 138.00      ,SINGLE FAMILY
# 3       43070   007 00 0-143.00       SINGLE FAMILY
# 4       22714   007-00 0 149.00       SINGLE FAMILY
# 5       48717   015 14 0 045.00       SINGLE FAMILY
# 6       18367   007 00 0 151.00       SINGLE FAMILY
# 7       19804   007 14 0 002.00       SINGLE FAMILY
# 8       54583   007 14 0 024.00       SINGLE FAMILY
# 9       36500   007 14 0 026.00       SINGLE FAMILY
# 10      19805   007-14 0 034.00       SINGLE FAMILY
# 11      29467  007 14 0A 024.00       SINGLE FAMILY
# 12      10754  007 14 0A 027.00       SINGLE FAMILY
# 13      34751  007 14 0B 010.00  /RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
#df['LandUse'].str.lstrip(',')

# %%
#df['LandUse']=df['LandUse'].str.lstrip(',')
#df['LandUse']=df['LandUse'].str.lstrip('/')
df['LandUse']=df['LandUse'].str.strip(',/')
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0,130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0-143.00      SINGLE FAMILY
# 4       22714   007-00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007-14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['ParcelID']=df['ParcelID'].str.replace('-', ' ')
df['ParcelID']=df['ParcelID'].str.replace(',', ' ')
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['ParcelID']
# Out:
# 0      007 00 0 125.00
# 1      007 00 0,130.00
# 2      007 00 0 138.00
# 3      007 00 0-143.00
# 4      007-00 0 149.00
# 5      015 14 0 045.00
# 6      007 00 0 151.00
# 7      007 14 0 002.00
# 8      007 14 0 024.00
# 9      007 14 0 026.00
# 10     007-14 0 034.00
# 11    007 14 0A 024.00
# 12    007 14 0A 027.00
# 13    007 14 0B 010.00
# Name: ParcelID, dtype: object

# %%
#df['ParcelID'].apply(lambda x: x[0:3] + ' ' + x[3:6] + ' '+ x[6:9] + '' )

# %%
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['PropertyAddress']
# Out:
# 0        1808  FOX CHASE DR, GOODLETTSVILLE
# 1        1832  FOX CHASE DR, GOODLETTSVILLE
# 2        1864 FOX CHASE  DR, GOODLETTSVILLE
# 3        1853  FOX CHASE DR, GOODLETTSVILLE
# 4        1829  FOX CHASE DR, GOODLETTSVILLE
# 5                    7515 GARY  RD, JOELTON
# 6        1821  FOX CHASE DR, GOODLETTSVILLE
# 7            2005  SADIE LN, GOODLETTSVILLE
# 8        1917 GRACELAND  DR, GOODLETTSVILLE
# 9     1428  SPRINGFIELD HWY, GOODLETTSVILLE
# 10    1420  SPRINGFIELD HWY, GOODLETTSVILLE
# 11           2209  KAYLA DR, GOODLETTSVILLE
# 12      109  BAILEY VIEW CT, GOODLETTSVILLE
# 13          1900  TINNIN RD, GOODLETTSVILLE
# Name: PropertyAddress, dtype: object

# %%
df['PropertyAddress'].str.split(',', expand = True)
# Out:
#                         0                1
# 0      1808  FOX CHASE DR   GOODLETTSVILLE
# 1      1832  FOX CHASE DR   GOODLETTSVILLE
# 2      1864 FOX CHASE  DR   GOODLETTSVILLE
# 3      1853  FOX CHASE DR   GOODLETTSVILLE
# 4      1829  FOX CHASE DR   GOODLETTSVILLE
# 5           7515 GARY  RD          JOELTON
# 6      1821  FOX CHASE DR   GOODLETTSVILLE
# 7          2005  SADIE LN   GOODLETTSVILLE
# 8      1917 GRACELAND  DR   GOODLETTSVILLE
# 9   1428  SPRINGFIELD HWY   GOODLETTSVILLE
# 10  1420  SPRINGFIELD HWY   GOODLETTSVILLE
# 11         2209  KAYLA DR   GOODLETTSVILLE
# 12    109  BAILEY VIEW CT   GOODLETTSVILLE
# 13        1900  TINNIN RD   GOODLETTSVILLE

# %%
df[['Property_Street_Address', 'Property_Location']]=df['PropertyAddress'].str.split(',', expand = True)
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['OwnerName']
# Out:
# 0                 FRAZIER, CYRENTHA LYNETTE
# 1                   BONER, CHARLES & LESLIE
# 2                 WILSON, JAMES E. & JOANNE
# 3                  BAKER, JAY K. & SUSAN E.
# 4        POST, CHRISTOPHER M. & SAMANTHA C.
# 5                       PORTER, BRIAN KELLY
# 6               FIELDS, KAREN L. & BRENT A.
# 7                                       NaN
# 8                   BAILOR, DARRELL & TAMMY
# 9             ROBERTS, MISTY L. & ROBERT M.
# 10                     LEE, JEFFREY & NANCY
# 11                                      NaN
# 12    HINTON, MICHAEL R. & CYNTHIA M. MOORE
# 13                                      NaN
# Name: OwnerName, dtype: object

# %%
df[['FirstOwner','SecondOwner']]=df['OwnerName'].str.split('&', expand = True)
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['FirstOwner']
# Out:
# 0     FRAZIER CYRENTHA LYNETTE
# 1               BONER CHARLES
# 2             WILSON JAMES E.
# 3                BAKER JAY K.
# 4         POST CHRISTOPHER M.
# 5           PORTER BRIAN KELLY
# 6             FIELDS KAREN L.
# 7                          NaN
# 8              BAILOR DARRELL
# 9            ROBERTS MISTY L.
# 10                LEE JEFFREY
# 11                         NaN
# 12          HINTON MICHAEL R.
# 13                         NaN
# Name: FirstOwner, dtype: object

# %%
df['FirstOwner']=df['FirstOwner'].str.replace(',', '')
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df['SoldAsVacant']=df['SoldAsVacant'].str.replace('Yes','Y')
df['SoldAsVacant']=df['SoldAsVacant'].str.replace('No','N')
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
df=df.fillna('')
df
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       48717   015 14 0 045.00      SINGLE FAMILY
# 6       18367   007 00 0 151.00      SINGLE FAMILY
# 7       19804   007 14 0 002.00      SINGLE FAMILY
# 8       54583   007 14 0 024.00      SINGLE FAMILY
# 9       36500   007 14 0 026.00      SINGLE FAMILY
# 10      19805   007 14 0 034.00      SINGLE FAMILY
# 11      29467  007 14 0A 024.00      SINGLE FAMILY
# 12      10754  007 14 0A 027.00      SINGLE FAMILY
# 13      34751  007 14 0B 010.00  RESIDENTIAL CONDO
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# ...

# %%
SoldAsVacant = ['Y']
df2=df[df['SoldAsVacant'].isin(SoldAsVacant)]

# %%
df2
# Out:
#     UniqueID           ParcelID          LandUse  \
# 1       16918   007 00 0 130.00    SINGLE FAMILY
# 2       54582   007 00 0 138.00    SINGLE FAMILY
# 6       18367   007 00 0 151.00    SINGLE FAMILY
# 8       54583   007 14 0 024.00    SINGLE FAMILY
# 12      10754  007 14 0A 027.00    SINGLE FAMILY
#
#                         PropertyAddress   SaleDate  SalePrice  \
# 1    1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2    1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 6    1821  FOX CHASE DR, GOODLETTSVILLE 2014-07-16     267000
# 8    1917 GRACELAND  DR, GOODLETTSVILLE 2016-09-27     262000
# 12  109  BAILEY VIEW CT, GOODLETTSVILLE 2013-12-12     585000
#
#       LegalReference SoldAsVacant                              OwnerName  \
# 1   20140619-0053768            Y                BONER, CHARLES & LESLIE
# 2   20160927-0101718            Y              WILSON, JAMES E. & JOANNE
# ...
