# %% [markdown]
# #Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Online Sales Data.csv")
#df.set_index('Payment Method')
#df.filter(items = ['Payment Method', 'Total Revenue'])
#df.groupby('Payment Method').sum()
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#df.plot(kind='bar', x='Payment Method')

# %%
df1 = pd.read_csv(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Online Sales Data.csv")
df1
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df1= df1.set_index('Payment Method')
df1.filter(items = ['Payment Method', 'Total Revenue'])
# Out:
#                 Total Revenue
# Payment Method
# Credit Card           1999.98
# PayPal                 499.99
# Debit Card             209.97
# Credit Card             63.96
# PayPal                  89.99
# ...                       ...
# PayPal                 159.99
# Debit Card             270.00
# Credit Card             32.97
# PayPal                  55.00
# Credit Card             59.98
#
# [240 rows x 1 columns]

# %%
df11=df1.groupby('Payment Method')['Total Revenue'].sum()
df11
# Out:
# Payment Method
# Credit Card    51170.86
# Debit Card      8128.93
# PayPal         21268.06
# Name: Total Revenue, dtype: float64

# %%
df11.plot(kind='bar', ylabel= 'Total Revenue')
# Out:
# <Axes: xlabel='Payment Method', ylabel='Total Revenue'>

# %%
df2 = pd.read_csv(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Online Sales Data.csv")
df2
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df21=df2.groupby('Payment Method').count().sort_values(by='Transaction ID')
df21
# Out:
#                 Transaction ID  Date  Product Category  Product Name  \
# Payment Method
# Debit Card                  40    40                40            40
# PayPal                      80    80                80            80
# Credit Card                120   120               120           120
#
#                 Units Sold  Unit Price  Total Revenue  Region
# Payment Method
# Debit Card              40          40             40      40
# PayPal                  80          80             80      80
# Credit Card            120         120            120     120

# %%
df21['Transaction ID'].plot(kind='bar',ylabel='Frequency of use', title='Most used payment methods')
# Out:
# <Axes: title={'center': 'Most used payment methods'}, xlabel='Payment Method', ylabel='Frequency of use'>

# %%
df3 = pd.read_csv(r"C:\Users\HP Pavilion\Desktop\Data analysis\Practices\personal project\Dataset for Portfolio\Online Sales Data.csv")
df3
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df31=df3.groupby('Product Category').sum().sort_values(by= 'Total Revenue', ascending=False)
df31
# Out:
#                   Transaction ID  \
# Product Category
# Electronics               404720
# Home Appliances           404760
# Sports                    404920
# Clothing                  404800
# Beauty Products           404880
# Books                     404840
#
#                                                                Date  \
# Product Category
# Electronics       2024-01-012024-01-072024-01-132024-01-192024-0...
# Home Appliances   2024-01-022024-01-082024-01-142024-01-202024-0...
# Sports            2024-01-062024-01-122024-01-182024-01-242024-0...
# Clothing          2024-01-032024-01-092024-01-152024-01-212024-0...
# Beauty Products   2024-01-052024-01-112024-01-172024-01-232024-0...
# Books             2024-01-042024-01-102024-01-162024-01-222024-0...
#
#                                                        Product Name  \
# Product Category
# Electronics       iPhone 14 ProMacBook Pro 16-inchSamsung Galaxy...
# ...

# %%
df31['Total Revenue'].plot(kind='bar')
# Out:
# <Axes: xlabel='Product Category'>

# %%
df21['Transaction ID'].plot(kind='pie',ylabel='Frequency of use', title='Most used payment methods')
# Out:
# <Axes: title={'center': 'Most used payment methods'}, ylabel='Frequency of use'>

# %%
df.plot()

# %%
df31['Total Revenue'].plot(kind='barh',)
# Out:
# <Axes: ylabel='Product Category'>
